# %%
import pandas as pd
from datetime import date, datetime

df = pd.DataFrame({'a_column': [True, False, None, 100, 0.01, date.today(), c, 'Nice']})

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   a_column  7 non-null      object
# dtypes: object(1)
# memory usage: 196.0+ bytes
#                      a_column
# 0                        True
# 1                       False
# 2                        None
# 3                         100
# 4                        0.01
# 5                  2025-11-27
# 6  2025-11-27 15:38:05.751407
# 7                        Nice

# %% [markdown]
# <h1>It looks like everything can be casted into 'string'</h1>

# %%
df = pd.DataFrame({'a_column': [True, False, None, 100, 0.01, date.today(), datetime.now(), 'Nice']})
df['a_column'] = df['a_column'].astype('string')

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   a_column  7 non-null      string
# dtypes: string(1)
# memory usage: 196.0 bytes
#                      a_column
# 0                        True
# 1                       False
# 2                        <NA>
# 3                         100
# 4                        0.01
# 5                  2025-11-27
# 6  2025-11-27 15:41:30.924560
# 7                        Nice
